# %%
Algorithm 5. Remaining useful life (RUL) estimation

Input:
    T = {t_k}                  : inspection or prediction time points
    D = {d_k}                  : corrosion depth evolution
    S = {s_k}                  : maximum von Mises stress at each time point
    s_fail                     : selected failure threshold

Output:
    t_RUL                      : predicted remaining useful life

Procedure:
1. For each time point t_k do
2.     Update corrosion depth d_k
3.     Reconstruct or update the defect geometry
4.     Run FE analysis and obtain stress s_k
5. End For
6. Construct the stress trajectory S(T)
7. Find the earliest time t_RUL such that:
       s(t_RUL) >= s_fail
8. If no intersection exists in the prediction horizon, report RUL > horizon
9. Return t_RUL
